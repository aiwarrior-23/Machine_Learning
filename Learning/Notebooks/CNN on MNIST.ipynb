# %%
from numpy import mean
from numpy import std
import pandas as pd
from matplotlib import pyplot
from sklearn.model_selection import KFold
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split

# %%
def load_dataset():
    # load dataset
    mnist_data = pd.read_csv("mnist_train.csv")
    # Find Traing and Test
    x_train, x_test, y_train, y_test = train_test_split(mnist_data.drop(["label"], axis=1), mnist_data[["label"]], test_size=0.20, random_state=42)
    
    # Conversion into Numpy
    y_train = y_train.to_numpy()
    x_train = x_train.to_numpy()
    x_test = x_test.to_numpy()
    y_test = y_test.to_numpy()
    
    # reshape dataset to have a single channel
    trainX = x_train.reshape((x_train.shape[0], 28, 28, 1))
    testX = x_test.reshape((x_test.shape[0], 28, 28, 1))
    
    # one hot encode target values
    trainY = to_categorical(y_train)
    testY = to_categorical(y_test)
    return trainX, trainY, testX, testY

x_train, y_train, x_test, y_test = load_dataset()

# %%
def prep_pixels(train, test):
	train_norm = train.astype('float32')
	test_norm = test.astype('float32')

	train_norm = train_norm / 255.0
	test_norm = test_norm / 255.0

	return train_norm, test_norm

x_train, x_test = prep_pixels(x_train, x_test)

# %%
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', 
                     kernel_initializer='he_uniform', 
                     input_shape=(28, 28, 1)))
	model.add(MaxPooling2D((2, 2)))
	model.add(Flatten())
	model.add(Dense(100, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(10, activation='softmax'))
	# compile model
	opt = SGD(lr=0.01, momentum=0.9)
	model.compile(optimizer=opt, loss='categorical_crossentropy', 
                  metrics=['accuracy'])
	return model

model = define_model()

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 5408)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               540900
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 542,230
# Trainable params: 542,230
# Non-trainable params: 0
# _________________________________________________________________

# %%
def evaluate_model(dataX, dataY, n_folds=10):
	scores, histories = list(), list()
	# prepare cross validation
	kfold = KFold(n_folds, shuffle=True, random_state=1)
	# enumerate splits
	for train_ix, test_ix in kfold.split(dataX):
		# define model
		model = define_model()
		# select rows for train and test
		trainX, trainY, testX, testY = dataX[train_ix], dataY[train_ix], dataX[test_ix], dataY[test_ix]
		# fit model
		history = model.fit(trainX, trainY, epochs=20, batch_size=64, 
                            validation_data=(testX, testY), verbose=2)
		# evaluate model
		_, acc = model.evaluate(testX, testY, verbose=2)
		print('> %.3f' % (acc * 100.0))
		# stores scores
		scores.append(acc)
		histories.append(history)
	return scores, histories

# %%
def summarize_diagnostics(histories):
	for i in range(len(histories)):
		# plot loss
		pyplot.subplot(2, 1, 1)
		pyplot.title('Cross Entropy Loss')
		pyplot.plot(histories[i].history['loss'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_loss'], color='orange', label='test')
		# plot accuracy
		pyplot.subplot(2, 1, 2)
		pyplot.title('Classification Accuracy')
		pyplot.plot(histories[i].history['accuracy'], color='blue', label='train')
		pyplot.plot(histories[i].history['val_accuracy'], color='orange', label='test')
	pyplot.show()
 
# summarize model performance
def summarize_performance(scores):
	# print summary
	print('Accuracy: mean=%.3f std=%.3f, n=%d' % (mean(scores)*100, std(scores)*100, len(scores)))
	# box and whisker plots of results
	pyplot.boxplot(scores)
	pyplot.show()

# %%
def run_test_harness(x_train, y_train, x_test, y_test):
	# load dataset
	trainX, trainY, testX, testY = x_train, y_train, x_test, y_test
	# evaluate model
	scores, histories = evaluate_model(trainX, trainY)
    	# learning curves
	summarize_diagnostics(histories)
	# summarize estimated performance
	summarize_performance(scores)

# %%
run_test_harness(x_train, y_train, x_test, y_test)
# Out:
# Train on 43200 samples, validate on 4800 samples
# Epoch 1/20
#  - 10s - loss: 0.2338 - accuracy: 0.9289 - val_loss: 0.1055 - val_accuracy: 0.9683
# Epoch 2/20
#  - 9s - loss: 0.0856 - accuracy: 0.9753 - val_loss: 0.0810 - val_accuracy: 0.9740
# Epoch 3/20
#  - 10s - loss: 0.0583 - accuracy: 0.9836 - val_loss: 0.0622 - val_accuracy: 0.9806
# Epoch 4/20
#  - 11s - loss: 0.0425 - accuracy: 0.9876 - val_loss: 0.0527 - val_accuracy: 0.9842
# Epoch 5/20
#  - 13s - loss: 0.0325 - accuracy: 0.9910 - val_loss: 0.0509 - val_accuracy: 0.9842
# Epoch 6/20
#  - 13s - loss: 0.0258 - accuracy: 0.9931 - val_loss: 0.0494 - val_accuracy: 0.9848
# Epoch 7/20
#  - 14s - loss: 0.0205 - accuracy: 0.9947 - val_loss: 0.0491 - val_accuracy: 0.9856
# Epoch 8/20
#  - 14s - loss: 0.0154 - accuracy: 0.9963 - val_loss: 0.0532 - val_accuracy: 0.9833
# Epoch 9/20
#  - 15s - loss: 0.0129 - accuracy: 0.9969 - val_loss: 0.0458 - val_accuracy: 0.9837
# Epoch 10/20
#  - 14s - loss: 0.0101 - accuracy: 0.9979 - val_loss: 0.0449 - val_accuracy: 0.9852
# Epoch 11/20
#  - 14s - loss: 0.0081 - accuracy: 0.9984 - val_loss: 0.0477 - val_accuracy: 0.9854
# Epoch 12/20
#  - 14s - loss: 0.0063 - accuracy: 0.9989 - val_loss: 0.0440 - val_accuracy: 0.9867
# Epoch 13/20
#  - 14s - loss: 0.0048 - accuracy: 0.9994 - val_loss: 0.0471 - val_accuracy: 0.9852
# Epoch 14/20
#  - 14s - loss: 0.0041 - accuracy: 0.9996 - val_loss: 0.0445 - val_accuracy: 0.9871
# Epoch 15/20
#  - 13s - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.0442 - val_accuracy: 0.9867
# Epoch 16/20
#  - 13s - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0451 - val_accuracy: 0.9862
# Epoch 17/20
#  - 13s - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.0452 - val_accuracy: 0.9865
# Epoch 18/20
#  - 13s - loss: 0.0018 - accuracy: 0.9999 - val_loss: 0.0457 - val_accuracy: 0.9865
# Epoch 19/20
#  - 13s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0469 - val_accuracy: 0.9862
# Epoch 20/20
#  - 13s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0479 - val_accuracy: 0.9856
# > 98.563
# Train on 43200 samples, validate on 4800 samples
# Epoch 1/20
#  - 14s - loss: 0.2437 - accuracy: 0.9259 - val_loss: 0.1300 - val_accuracy: 0.9602
# Epoch 2/20
#  - 13s - loss: 0.0961 - accuracy: 0.9715 - val_loss: 0.0962 - val_accuracy: 0.9698
# Epoch 3/20
#  - 13s - loss: 0.0634 - accuracy: 0.9812 - val_loss: 0.0684 - val_accuracy: 0.9800
# Epoch 4/20
#  - 13s - loss: 0.0448 - accuracy: 0.9873 - val_loss: 0.0594 - val_accuracy: 0.9815
# Epoch 5/20
#  - 13s - loss: 0.0343 - accuracy: 0.9900 - val_loss: 0.0640 - val_accuracy: 0.9794
# Epoch 6/20
#  - 13s - loss: 0.0264 - accuracy: 0.9927 - val_loss: 0.0549 - val_accuracy: 0.9829
# Epoch 7/20
#  - 13s - loss: 0.0203 - accuracy: 0.9942 - val_loss: 0.0535 - val_accuracy: 0.9852
# Epoch 8/20
#  - 13s - loss: 0.0157 - accuracy: 0.9959 - val_loss: 0.0520 - val_accuracy: 0.9850
# Epoch 9/20
#  - 13s - loss: 0.0129 - accuracy: 0.9969 - val_loss: 0.0627 - val_accuracy: 0.9810
# Epoch 10/20
#  - 13s - loss: 0.0096 - accuracy: 0.9980 - val_loss: 0.0567 - val_accuracy: 0.9827
# Epoch 11/20
#  - 13s - loss: 0.0075 - accuracy: 0.9986 - val_loss: 0.0558 - val_accuracy: 0.9848
# Epoch 12/20
#  - 13s - loss: 0.0055 - accuracy: 0.9995 - val_loss: 0.0563 - val_accuracy: 0.9854
# Epoch 13/20
#  - 13s - loss: 0.0047 - accuracy: 0.9994 - val_loss: 0.0568 - val_accuracy: 0.9854
# Epoch 14/20
#  - 13s - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.0557 - val_accuracy: 0.9831
# Epoch 15/20
#  - 13s - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0574 - val_accuracy: 0.9827
# Epoch 16/20
#  - 13s - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.0581 - val_accuracy: 0.9842
# Epoch 17/20
#  - 13s - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.0571 - val_accuracy: 0.9844
# Epoch 18/20
#  - 13s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0590 - val_accuracy: 0.9844
# Epoch 19/20
#  - 13s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0591 - val_accuracy: 0.9852
# Epoch 20/20
#  - 13s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0593 - val_accuracy: 0.9856
# > 98.563
# Train on 43200 samples, validate on 4800 samples
# Epoch 1/20
#  - 13s - loss: 0.2322 - accuracy: 0.9287 - val_loss: 0.1399 - val_accuracy: 0.9588
# Epoch 2/20
#  - 13s - loss: 0.0899 - accuracy: 0.9729 - val_loss: 0.0918 - val_accuracy: 0.9733
# Epoch 3/20
#  - 13s - loss: 0.0607 - accuracy: 0.9821 - val_loss: 0.0774 - val_accuracy: 0.9800
# Epoch 4/20
#  - 13s - loss: 0.0450 - accuracy: 0.9869 - val_loss: 0.0813 - val_accuracy: 0.9769
# Epoch 5/20
#  - 13s - loss: 0.0354 - accuracy: 0.9892 - val_loss: 0.0650 - val_accuracy: 0.9815
# Epoch 6/20
#  - 13s - loss: 0.0276 - accuracy: 0.9917 - val_loss: 0.0794 - val_accuracy: 0.9777
# Epoch 7/20
#  - 13s - loss: 0.0216 - accuracy: 0.9940 - val_loss: 0.0692 - val_accuracy: 0.9819
# Epoch 8/20
#  - 13s - loss: 0.0168 - accuracy: 0.9954 - val_loss: 0.0597 - val_accuracy: 0.9848
# Epoch 9/20
#  - 13s - loss: 0.0132 - accuracy: 0.9965 - val_loss: 0.0657 - val_accuracy: 0.9823
# Epoch 10/20
#  - 13s - loss: 0.0111 - accuracy: 0.9973 - val_loss: 0.0633 - val_accuracy: 0.9844
# Epoch 11/20
#  - 13s - loss: 0.0076 - accuracy: 0.9985 - val_loss: 0.0586 - val_accuracy: 0.9854
# Epoch 12/20
#  - 13s - loss: 0.0060 - accuracy: 0.9991 - val_loss: 0.0648 - val_accuracy: 0.9844
# Epoch 13/20
#  - 13s - loss: 0.0050 - accuracy: 0.9993 - val_loss: 0.0639 - val_accuracy: 0.9848
# Epoch 14/20
#  - 13s - loss: 0.0041 - accuracy: 0.9995 - val_loss: 0.0663 - val_accuracy: 0.9860
# Epoch 15/20
#  - 13s - loss: 0.0035 - accuracy: 0.9996 - val_loss: 0.0630 - val_accuracy: 0.9869
# Epoch 16/20
#  - 13s - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.0664 - val_accuracy: 0.9846
# Epoch 17/20
#  - 13s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9846
# Epoch 18/20
#  - 13s - loss: 0.0018 - accuracy: 0.9999 - val_loss: 0.0656 - val_accuracy: 0.9860
# Epoch 19/20
#  - 13s - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.0664 - val_accuracy: 0.9858
# Epoch 20/20
#  - 13s - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.0679 - val_accuracy: 0.9865
# > 98.646
# Train on 43200 samples, validate on 4800 samples
# Epoch 1/20
#  - 14s - loss: 0.2601 - accuracy: 0.9207 - val_loss: 0.1319 - val_accuracy: 0.9592
# Epoch 2/20
#  - 13s - loss: 0.1065 - accuracy: 0.9685 - val_loss: 0.0899 - val_accuracy: 0.9706
# Epoch 3/20
#  - 13s - loss: 0.0687 - accuracy: 0.9794 - val_loss: 0.0744 - val_accuracy: 0.9777
# Epoch 4/20
#  - 13s - loss: 0.0518 - accuracy: 0.9847 - val_loss: 0.0603 - val_accuracy: 0.9808
# Epoch 5/20
#  - 13s - loss: 0.0386 - accuracy: 0.9886 - val_loss: 0.0647 - val_accuracy: 0.9823
# Epoch 6/20
#  - 13s - loss: 0.0297 - accuracy: 0.9916 - val_loss: 0.0569 - val_accuracy: 0.9831
# Epoch 7/20
#  - 13s - loss: 0.0237 - accuracy: 0.9932 - val_loss: 0.0533 - val_accuracy: 0.9844
# Epoch 8/20
#  - 13s - loss: 0.0195 - accuracy: 0.9945 - val_loss: 0.0571 - val_accuracy: 0.9821
# Epoch 9/20
#  - 13s - loss: 0.0145 - accuracy: 0.9960 - val_loss: 0.0583 - val_accuracy: 0.9837
# Epoch 10/20
#  - 13s - loss: 0.0118 - accuracy: 0.9974 - val_loss: 0.0539 - val_accuracy: 0.9862
# Epoch 11/20
#  - 13s - loss: 0.0088 - accuracy: 0.9983 - val_loss: 0.0531 - val_accuracy: 0.9862
# Epoch 12/20
#  - 13s - loss: 0.0067 - accuracy: 0.9988 - val_loss: 0.0519 - val_accuracy: 0.9873
# Epoch 13/20
#  - 13s - loss: 0.0057 - accuracy: 0.9989 - val_loss: 0.0526 - val_accuracy: 0.9860
# Epoch 14/20
#  - 13s - loss: 0.0043 - accuracy: 0.9994 - val_loss: 0.0565 - val_accuracy: 0.9850
# Epoch 15/20
#  - 13s - loss: 0.0036 - accuracy: 0.9996 - val_loss: 0.0559 - val_accuracy: 0.9860
# Epoch 16/20
#  - 13s - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.0532 - val_accuracy: 0.9867
# Epoch 17/20
#  - 13s - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.0567 - val_accuracy: 0.9877
# Epoch 18/20
#  - 13s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9867
# Epoch 19/20
#  - 13s - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0567 - val_accuracy: 0.9871
# Epoch 20/20
#  - 13s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 0.9873
# > 98.729
# Train on 43200 samples, validate on 4800 samples
# Epoch 1/20
#  - 14s - loss: 0.2440 - accuracy: 0.9248 - val_loss: 0.1301 - val_accuracy: 0.9606
# Epoch 2/20
#  - 13s - loss: 0.0901 - accuracy: 0.9738 - val_loss: 0.0965 - val_accuracy: 0.9688
# Epoch 3/20
#  - 12s - loss: 0.0614 - accuracy: 0.9820 - val_loss: 0.0795 - val_accuracy: 0.9740
# Epoch 4/20
#  - 12s - loss: 0.0447 - accuracy: 0.9864 - val_loss: 0.0792 - val_accuracy: 0.9735
# Epoch 5/20
#  - 12s - loss: 0.0342 - accuracy: 0.9901 - val_loss: 0.0623 - val_accuracy: 0.9798
# Epoch 6/20
#  - 12s - loss: 0.0264 - accuracy: 0.9930 - val_loss: 0.0532 - val_accuracy: 0.9800
# Epoch 7/20
#  - 12s - loss: 0.0206 - accuracy: 0.9942 - val_loss: 0.0668 - val_accuracy: 0.9779
# Epoch 8/20
#  - 13s - loss: 0.0166 - accuracy: 0.9958 - val_loss: 0.0601 - val_accuracy: 0.9808
# Epoch 9/20
#  - 13s - loss: 0.0125 - accuracy: 0.9973 - val_loss: 0.0542 - val_accuracy: 0.9819
# Epoch 10/20
#  - 13s - loss: 0.0100 - accuracy: 0.9978 - val_loss: 0.0552 - val_accuracy: 0.9819
# Epoch 11/20
#  - 13s - loss: 0.0082 - accuracy: 0.9985 - val_loss: 0.0550 - val_accuracy: 0.9831
# Epoch 12/20
#  - 13s - loss: 0.0060 - accuracy: 0.9992 - val_loss: 0.0558 - val_accuracy: 0.9831
# Epoch 13/20
#  - 14s - loss: 0.0051 - accuracy: 0.9993 - val_loss: 0.0524 - val_accuracy: 0.9840
# Epoch 14/20
#  - 15s - loss: 0.0036 - accuracy: 0.9997 - val_loss: 0.0621 - val_accuracy: 0.9817
# Epoch 15/20
#  - 16s - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0604 - val_accuracy: 0.9810
# Epoch 16/20
#  - 15s - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0563 - val_accuracy: 0.9833
# Epoch 17/20
#  - 15s - loss: 0.0021 - accuracy: 0.9999 - val_loss: 0.0582 - val_accuracy: 0.9831
# Epoch 18/20
#  - 15s - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.0555 - val_accuracy: 0.9835
# Epoch 19/20
#  - 14s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0580 - val_accuracy: 0.9846
# Epoch 20/20
#  - 14s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0583 - val_accuracy: 0.9837
# > 98.375
# Train on 43200 samples, validate on 4800 samples
# Epoch 1/20
#  - 14s - loss: 0.2462 - accuracy: 0.9250 - val_loss: 0.1212 - val_accuracy: 0.9644
# Epoch 2/20
#  - 13s - loss: 0.0891 - accuracy: 0.9747 - val_loss: 0.0763 - val_accuracy: 0.9779
# Epoch 3/20
#  - 13s - loss: 0.0583 - accuracy: 0.9826 - val_loss: 0.0598 - val_accuracy: 0.9825
# Epoch 4/20
#  - 13s - loss: 0.0440 - accuracy: 0.9876 - val_loss: 0.0649 - val_accuracy: 0.9810
# Epoch 5/20
#  - 13s - loss: 0.0329 - accuracy: 0.9909 - val_loss: 0.0533 - val_accuracy: 0.9846
# Epoch 6/20
#  - 13s - loss: 0.0263 - accuracy: 0.9922 - val_loss: 0.0536 - val_accuracy: 0.9846
# Epoch 7/20
#  - 13s - loss: 0.0197 - accuracy: 0.9949 - val_loss: 0.0497 - val_accuracy: 0.9860
# Epoch 8/20
#  - 14s - loss: 0.0162 - accuracy: 0.9958 - val_loss: 0.0517 - val_accuracy: 0.9842
# Epoch 9/20
#  - 16s - loss: 0.0127 - accuracy: 0.9971 - val_loss: 0.0519 - val_accuracy: 0.9848
# Epoch 10/20
#  - 16s - loss: 0.0102 - accuracy: 0.9981 - val_loss: 0.0507 - val_accuracy: 0.9846
# Epoch 11/20
#  - 15s - loss: 0.0079 - accuracy: 0.9985 - val_loss: 0.0488 - val_accuracy: 0.9865
# Epoch 12/20
#  - 16s - loss: 0.0061 - accuracy: 0.9992 - val_loss: 0.0521 - val_accuracy: 0.9860
# Epoch 13/20
#  - 20s - loss: 0.0050 - accuracy: 0.9995 - val_loss: 0.0488 - val_accuracy: 0.9862
# Epoch 14/20
#  - 19s - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.0498 - val_accuracy: 0.9873
# Epoch 15/20
#  - 20s - loss: 0.0032 - accuracy: 0.9998 - val_loss: 0.0500 - val_accuracy: 0.9869
# Epoch 16/20
#  - 21s - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0517 - val_accuracy: 0.9860
# Epoch 17/20
#  - 21s - loss: 0.0022 - accuracy: 0.9998 - val_loss: 0.0522 - val_accuracy: 0.9860
# Epoch 18/20
#  - 21s - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.0527 - val_accuracy: 0.9867
# Epoch 19/20
#  - 21s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0510 - val_accuracy: 0.9871
# Epoch 20/20
#  - 19s - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.0537 - val_accuracy: 0.9860
# > 98.604
# Train on 43200 samples, validate on 4800 samples
# Epoch 1/20
#  - 19s - loss: 0.2614 - accuracy: 0.9209 - val_loss: 0.1280 - val_accuracy: 0.9638
# Epoch 2/20
#  - 17s - loss: 0.0992 - accuracy: 0.9712 - val_loss: 0.0939 - val_accuracy: 0.9706
# Epoch 3/20
#  - 17s - loss: 0.0645 - accuracy: 0.9811 - val_loss: 0.0707 - val_accuracy: 0.9781
# Epoch 4/20
#  - 20s - loss: 0.0466 - accuracy: 0.9866 - val_loss: 0.0614 - val_accuracy: 0.9800
# Epoch 5/20
#  - 22s - loss: 0.0357 - accuracy: 0.9894 - val_loss: 0.0564 - val_accuracy: 0.9810
# Epoch 6/20
#  - 22s - loss: 0.0277 - accuracy: 0.9920 - val_loss: 0.0528 - val_accuracy: 0.9823
# Epoch 7/20
#  - 24s - loss: 0.0215 - accuracy: 0.9944 - val_loss: 0.0475 - val_accuracy: 0.9848
# Epoch 8/20
#  - 24s - loss: 0.0166 - accuracy: 0.9956 - val_loss: 0.0525 - val_accuracy: 0.9825
# Epoch 9/20
#  - 24s - loss: 0.0134 - accuracy: 0.9967 - val_loss: 0.0492 - val_accuracy: 0.9850
# Epoch 10/20
#  - 20s - loss: 0.0109 - accuracy: 0.9975 - val_loss: 0.0515 - val_accuracy: 0.9856
# Epoch 11/20
#  - 19s - loss: 0.0079 - accuracy: 0.9985 - val_loss: 0.0469 - val_accuracy: 0.9862
# Epoch 12/20
#  - 19s - loss: 0.0061 - accuracy: 0.9991 - val_loss: 0.0456 - val_accuracy: 0.9854
# Epoch 13/20
#  - 19s - loss: 0.0049 - accuracy: 0.9994 - val_loss: 0.0453 - val_accuracy: 0.9858
# Epoch 14/20
#  - 22s - loss: 0.0039 - accuracy: 0.9997 - val_loss: 0.0461 - val_accuracy: 0.9852
# Epoch 15/20
#  - 20s - loss: 0.0032 - accuracy: 0.9998 - val_loss: 0.0458 - val_accuracy: 0.9873
# Epoch 16/20
#  - 17s - loss: 0.0025 - accuracy: 0.9999 - val_loss: 0.0471 - val_accuracy: 0.9862
# Epoch 17/20
#  - 18s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0485 - val_accuracy: 0.9862
# Epoch 18/20
#  - 18s - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.0483 - val_accuracy: 0.9875
# Epoch 19/20
#  - 19s - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0479 - val_accuracy: 0.9877
# Epoch 20/20
#  - 21s - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.0471 - val_accuracy: 0.9875
# > 98.750
# Train on 43200 samples, validate on 4800 samples
# Epoch 1/20
#  - 21s - loss: 0.2440 - accuracy: 0.9248 - val_loss: 0.1295 - val_accuracy: 0.9658
# Epoch 2/20
#  - 20s - loss: 0.0911 - accuracy: 0.9730 - val_loss: 0.0862 - val_accuracy: 0.9744
# Epoch 3/20
#  - 19s - loss: 0.0609 - accuracy: 0.9820 - val_loss: 0.0705 - val_accuracy: 0.9800
# Epoch 4/20
#  - 22s - loss: 0.0437 - accuracy: 0.9870 - val_loss: 0.0828 - val_accuracy: 0.9771
# Epoch 5/20
#  - 23s - loss: 0.0353 - accuracy: 0.9901 - val_loss: 0.0656 - val_accuracy: 0.9829
# Epoch 6/20
#  - 21s - loss: 0.0259 - accuracy: 0.9928 - val_loss: 0.0634 - val_accuracy: 0.9821
# Epoch 7/20
#  - 21s - loss: 0.0202 - accuracy: 0.9946 - val_loss: 0.0649 - val_accuracy: 0.9833
# Epoch 8/20
#  - 22s - loss: 0.0151 - accuracy: 0.9964 - val_loss: 0.0653 - val_accuracy: 0.9823
# Epoch 9/20
#  - 20s - loss: 0.0131 - accuracy: 0.9965 - val_loss: 0.0596 - val_accuracy: 0.9833
# Epoch 10/20
#  - 18s - loss: 0.0100 - accuracy: 0.9979 - val_loss: 0.0658 - val_accuracy: 0.9833
# Epoch 11/20
#  - 16s - loss: 0.0073 - accuracy: 0.9988 - val_loss: 0.0619 - val_accuracy: 0.9837
# Epoch 12/20
#  - 16s - loss: 0.0054 - accuracy: 0.9994 - val_loss: 0.0641 - val_accuracy: 0.9837
# Epoch 13/20
#  - 15s - loss: 0.0042 - accuracy: 0.9995 - val_loss: 0.0595 - val_accuracy: 0.9858
# Epoch 14/20
#  - 15s - loss: 0.0033 - accuracy: 0.9998 - val_loss: 0.0610 - val_accuracy: 0.9862
# Epoch 15/20
#  - 14s - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0612 - val_accuracy: 0.9860
# Epoch 16/20
#  - 15s - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.0619 - val_accuracy: 0.9862
# Epoch 17/20
#  - 14s - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.0653 - val_accuracy: 0.9846
# Epoch 18/20
#  - 14s - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0659 - val_accuracy: 0.9858
# Epoch 19/20
#  - 13s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9854
# Epoch 20/20
#  - 14s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9858
# > 98.583
# Train on 43200 samples, validate on 4800 samples
# Epoch 1/20
#  - 15s - loss: 0.2509 - accuracy: 0.9230 - val_loss: 0.1537 - val_accuracy: 0.9571
# Epoch 2/20
#  - 15s - loss: 0.0898 - accuracy: 0.9739 - val_loss: 0.0980 - val_accuracy: 0.9717
# Epoch 3/20
#  - 16s - loss: 0.0580 - accuracy: 0.9835 - val_loss: 0.0786 - val_accuracy: 0.9779
# Epoch 4/20
#  - 15s - loss: 0.0435 - accuracy: 0.9875 - val_loss: 0.0649 - val_accuracy: 0.9810
# Epoch 5/20
#  - 16s - loss: 0.0334 - accuracy: 0.9903 - val_loss: 0.0651 - val_accuracy: 0.9815
# Epoch 6/20
#  - 16s - loss: 0.0256 - accuracy: 0.9926 - val_loss: 0.0621 - val_accuracy: 0.9823
# Epoch 7/20
#  - 15s - loss: 0.0208 - accuracy: 0.9944 - val_loss: 0.0561 - val_accuracy: 0.9831
# Epoch 8/20
#  - 14s - loss: 0.0156 - accuracy: 0.9961 - val_loss: 0.0598 - val_accuracy: 0.9821
# Epoch 9/20
#  - 13s - loss: 0.0122 - accuracy: 0.9973 - val_loss: 0.0600 - val_accuracy: 0.9817
# Epoch 10/20
#  - 13s - loss: 0.0093 - accuracy: 0.9983 - val_loss: 0.0579 - val_accuracy: 0.9840
# Epoch 11/20
#  - 13s - loss: 0.0079 - accuracy: 0.9987 - val_loss: 0.0565 - val_accuracy: 0.9829
# Epoch 12/20
#  - 13s - loss: 0.0062 - accuracy: 0.9991 - val_loss: 0.0593 - val_accuracy: 0.9846
# Epoch 13/20
#  - 12s - loss: 0.0049 - accuracy: 0.9994 - val_loss: 0.0629 - val_accuracy: 0.9835
# Epoch 14/20
#  - 12s - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.0600 - val_accuracy: 0.9848
# Epoch 15/20
#  - 12s - loss: 0.0033 - accuracy: 0.9995 - val_loss: 0.0620 - val_accuracy: 0.9846
# Epoch 16/20
#  - 12s - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.0608 - val_accuracy: 0.9846
# Epoch 17/20
#  - 12s - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.0629 - val_accuracy: 0.9850
# Epoch 18/20
#  - 12s - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0655 - val_accuracy: 0.9842
# Epoch 19/20
#  - 12s - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0643 - val_accuracy: 0.9852
# Epoch 20/20
#  - 12s - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.0631 - val_accuracy: 0.9852
# > 98.521
# Train on 43200 samples, validate on 4800 samples
# Epoch 1/20
#  - 13s - loss: 0.2426 - accuracy: 0.9259 - val_loss: 0.1110 - val_accuracy: 0.9673
# Epoch 2/20
#  - 12s - loss: 0.0893 - accuracy: 0.9742 - val_loss: 0.0753 - val_accuracy: 0.9783
# Epoch 3/20
#  - 12s - loss: 0.0583 - accuracy: 0.9832 - val_loss: 0.0643 - val_accuracy: 0.9812
# Epoch 4/20
#  - 12s - loss: 0.0419 - accuracy: 0.9874 - val_loss: 0.0528 - val_accuracy: 0.9852
# Epoch 5/20
#  - 13s - loss: 0.0321 - accuracy: 0.9909 - val_loss: 0.0578 - val_accuracy: 0.9835
# Epoch 6/20
#  - 13s - loss: 0.0251 - accuracy: 0.9928 - val_loss: 0.0467 - val_accuracy: 0.9860
# Epoch 7/20
#  - 14s - loss: 0.0190 - accuracy: 0.9949 - val_loss: 0.0528 - val_accuracy: 0.9842
# Epoch 8/20
#  - 15s - loss: 0.0153 - accuracy: 0.9959 - val_loss: 0.0471 - val_accuracy: 0.9871
# Epoch 9/20
#  - 15s - loss: 0.0121 - accuracy: 0.9969 - val_loss: 0.0491 - val_accuracy: 0.9869
# Epoch 10/20
#  - 15s - loss: 0.0095 - accuracy: 0.9980 - val_loss: 0.0483 - val_accuracy: 0.9867
# Epoch 11/20
#  - 14s - loss: 0.0070 - accuracy: 0.9986 - val_loss: 0.0446 - val_accuracy: 0.9873
# Epoch 12/20
#  - 15s - loss: 0.0053 - accuracy: 0.9994 - val_loss: 0.0481 - val_accuracy: 0.9865
# Epoch 13/20
#  - 13s - loss: 0.0040 - accuracy: 0.9997 - val_loss: 0.0486 - val_accuracy: 0.9873
# Epoch 14/20
#  - 14s - loss: 0.0033 - accuracy: 0.9998 - val_loss: 0.0460 - val_accuracy: 0.9879
# Epoch 15/20
#  - 13s - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0479 - val_accuracy: 0.9879
# Epoch 16/20
#  - 13s - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0478 - val_accuracy: 0.9881
# Epoch 17/20
#  - 12s - loss: 0.0020 - accuracy: 0.9999 - val_loss: 0.0479 - val_accuracy: 0.9885
# Epoch 18/20
#  - 12s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0483 - val_accuracy: 0.9877
# Epoch 19/20
#  - 12s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0496 - val_accuracy: 0.9875
# Epoch 20/20
#  - 12s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0506 - val_accuracy: 0.9879
# > 98.792
# /Users/ag78400/opt/anaconda3/envs/AI_for_Healthcare/lib/python3.7/site-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.
# /Users/ag78400/opt/anaconda3/envs/AI_for_Healthcare/lib/python3.7/site-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if __name__ == '__main__':
# Accuracy: mean=98.613 std=0.117, n=10
